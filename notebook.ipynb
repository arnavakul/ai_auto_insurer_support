# %% [markdown]
# Chatbot Testing and Graph

# %% [markdown]
# Graph

# %%
print("Test")
# Out:
# Test

# %%
from langgraph.graph import StateGraph, START, END

from agent.head_agent.state.head_state import HeadState

from agent.head_agent.nodes import (
    file_node,
    cost_estimation_node,
    verification_node,
    organization_node,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 from langgraph.graph import StateGraph, START, END
#       2
# ----> 3 from agent.head_agent.state.head_state import HeadState
#       4
#       5 from agent.head_agent.nodes import (
#       6     file_node,
#
# File c:\Cisco\Programming\ai_claim_assistant\agent\head_agent\state\head_state.py:7
#       4 from langgraph.graph.message import add_messages
#       6 from ...file_agent.state.document_info_state import DocumentInfo
# ----> 7 from ...verification_agent.state.verification_agent_state import (
#       8     CustomerClaimInfo,
#       9     VerificationResult
#      10 )
#      12 from ...cost_estimate_agent.state.agent_state import CostEstimate
#      13 from ...organizational_agent.state.state import OrganizedClaimPackage
#
# File c:\Cisco\Programming\ai_claim_assistant\agent\verification_agent\state\verification_agent_state.py:1
# ----> 1 from file_agent.state.document_info_state import DocumentInfo
#       2 from head_agent.state.input_state import InputState
#       3 from pydantic import BaseModel
#
# ModuleNotFoundError: No module named 'file_agent'
